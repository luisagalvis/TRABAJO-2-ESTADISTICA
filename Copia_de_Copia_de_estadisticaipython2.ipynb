# %% [markdown]
# <a href="https://colab.research.google.com/github/luisagalvis/TRABAJO-2-ESTADISTICA/blob/main/Copia_de_Copia_de_estadisticaipython2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files # Para cargar archivos en google colab
import pandas as pd
import io
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# # Estadística descriptiva para variables cualitativas
#
#
# *   Gráficos para datos de una variable cualitativa
# *   Proporciones asociadas a los valores de una variable cualitativa
#
# **Trabajo Tercer Parcial Parte Práctica**
#
#
# **INTEGRANTES**
#
#
# *   Luisa Galvis - 2203044
# *   Lizeth Sánchez - 2202869
# *   Oscar Ariza - 2202502
# *   Daniel Carillo - 2192309

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4e3ece12-f191-4bcf-8b66-25ce6ab73963" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4e3ece12-f191-4bcf-8b66-25ce6ab73963">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
io_csv = io.BytesIO(uploaded['nac2020.csv'])
tabla = pd.read_csv(io_csv, sep = ",", index_col=0, encoding='latin-1')
tabla.head(3)
# Out:
#           COD_MUNIC  AREANAC  SIT_PARTO OTRO_SIT  SEXO  PESO_NAC  TALLA_NAC  \
# COD_DPTO
# 44              560        3          2      NaN     2         9          9
# 44              560        3          2      NaN     1         9          9
# 44              560        3          2      NaN     1         9          9
#
#            ANO  MES  ATEN_PAR  ...  AREA_RES  N_HIJOSV  FECHA_NACM  N_EMB  \
# COD_DPTO                       ...
# 44        2020   11         5  ...       3.0         1         NaN      1
# 44        2020   10         5  ...       3.0         1         NaN      1
# 44        2020   10         5  ...       3.0         1         NaN      1
#
#           SEG_SOCIAL  IDCLASADMI  EDAD_PADRE  NIV_EDUP  ULTCURPAD  PROFESION
# COD_DPTO
# 44                 2         2.0          20        99         99          5
# 44                 2         2.0          20        99         99          5
# ...

# %%
tabla1 = tabla[["T_GES", "TALLA_NAC"]]
tabla1.head(4)
# Out:
#           T_GES  TALLA_NAC
# COD_DPTO
# 44            6          9
# 44            6          9
# 44            6          9
# 44            6          9

# %%
df2 = tabla1[(tabla1["T_GES"] != 9) & (tabla1.TALLA_NAC != 9)]
df2.head(4)
# Out:
#           T_GES  TALLA_NAC
# COD_DPTO
# 52            4          4
# 20            4          5
# 27            4          5
# 27            4          4

# %%
df2.T_GES.head(2)
df2.T_GES = df2.T_GES.astype(str)
df2.T_GES.head(2)
# Out:
# <ipython-input-7-e608aef629bf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.T_GES = df2.T_GES.astype(str)
# COD_DPTO
# 52    4
# 20    4
# Name: T_GES, dtype: object

# %%
df2.TALLA_NAC.head(2)
df2.TALLA_NAC = df2.TALLA_NAC.astype(str)
df2.TALLA_NAC.head(2)
# Out:
# <ipython-input-8-4ae3ab049010>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.TALLA_NAC = df2.TALLA_NAC.astype(str)
# COD_DPTO
# 52    4
# 20    5
# Name: TALLA_NAC, dtype: object

# %%
df2.loc[(df2.T_GES == "1"), "T_GES"], df2.loc[(df2.T_GES == "2"), "T_GES"] ="1-21", "22-27"
df2.loc[(df2.T_GES == "3"), "T_GES"],df2.loc[(df2.T_GES == "4"), 'T_GES'] = "28-37", "38-41"
df2.loc[(df2.T_GES == "5"), 'T_GES'], df2.loc[(df2.T_GES == "6"), 'T_GES'], df2.loc[(df2.T_GES == "9"), 'T_GES'] = ">42", "Ignorado", "NA"
df2.head(5)
# Out:
#           T_GES TALLA_NAC
# COD_DPTO
# 52        38-41         4
# 20        38-41         5
# 27        38-41         5
# 27        38-41         4
# 27        38-41         5

# %%
df2.loc[(df2.TALLA_NAC == "1"), "TALLA_NAC"], df2.loc[(df2.TALLA_NAC == "2"), "TALLA_NAC"] ="1-19", "20-29"
df2.loc[(df2.TALLA_NAC == "3"), "TALLA_NAC"],df2.loc[(df2.TALLA_NAC == "4"), 'TALLA_NAC'] = "30-39", "40-49"
df2.loc[(df2.TALLA_NAC == "5"), 'TALLA_NAC'], df2.loc[(df2.TALLA_NAC == "6"), 'TALLA_NAC'], df2.loc[(df2.TALLA_NAC == "9"), 'TALLA_NAC'] = "50-59", ">60", "NA"
df2.head(5)
# Out:
#           T_GES TALLA_NAC
# COD_DPTO
# 52        38-41     40-49
# 20        38-41     50-59
# 27        38-41     50-59
# 27        38-41     40-49
# 27        38-41     50-59

# %%
x_values1 = df2.T_GES.unique()
y_values1 = df2.T_GES.value_counts().tolist()
plt.bar(x_values1, y_values1, color = "purple")
plt.title('Tiempo de gestación del nacido vivo')
ax = plt.subplot()  # Axis
ax.set_xlabel('Tiempo de gestación (rango en semanas) ')
ax.set_ylabel('Frecuencia')
plt.show()

# %% [markdown]
# El gráfico muestra que la categoría más frecuente es la de "38-41 semanas", con más de 400.000 nacimientos vivos. Esto significa que la mayoría de los bebés nacen entre las semanas 38 y 41 de gestación.. Por otro lado, las semanas 22-27, 28-37, y mayores a 42.. es un numero reducido de embarazos. como hay una informacion ignorada respecto al rango de semanas, se puede deducir que es posible que algunos bebés nazcan prematuros ya que hay mas de 1000.000 nacidos en ese tiempo de gestación

# %%
sizes = np.array(y_values1)
sizes
# Out:
# array([485433, 130485,   2236,   1482,   1163,     28])

# %%
plt.pie(y_values1, labels = x_values1, autopct='%1.1f%%')
plt.show()

# %%
x_values2 = df2.TALLA_NAC.unique()
y_values2 = df2.TALLA_NAC.value_counts().tolist()
plt.bar(x_values2, y_values2, color = "blueviolet")
plt.title('Talla del nacido vivo, al nacer en Colombia')
ax = plt.subplot()  # Axis
ax.set_xlabel('Talla del nacido (rango) ')
ax.set_ylabel('Frecuencia')
plt.show()

# %% [markdown]
# El gráfico muestra que la categoría más frecuente es la de "40-49 cm", con más de 350.000 nacimientos vivos. Esto significa que la mayoría de los bebés en Colombia nacen con una talla entre 40 y 49 centímetros...Las categorías de "50-59 cm" y "30-39" son relativamente frecuentes, el primero con 250.000 y el segundo rango con menos de 50.000 nacimientos vivos en total... Es decir, que algunos niños nacen pequeños.

# %%
sizes = np.array(y_values2)
sizes
# Out:
# array([361444, 253072,   5716,    478,    115,      2])

# %%
plt.pie(y_values2, labels = x_values2, autopct='%1.1f%%')
plt.show()

# %%
len(df2.T_GES)
# Out:
# 620827

# %%
len(df2.TALLA_NAC)
# Out:
# 620827

# %%
porcentaje = [(x/len(df2.T_GES)*100) for x in y_values1]
print(x_values1)
print(porcentaje)
# Out:
# ['38-41' 'Ignorado' '28-37' '22-27' '>42' '1-21']
# [78.19134799227481, 21.017932531929183, 0.3601647479893754, 0.23871384459760933, 0.18733077008570825, 0.004510113123301661]

# %% [markdown]
# Aproximadamente el 78% de los niños nacidos en Colombia tiene entre 38 y 41 semanas de gestación, el 21% entre semanas de gestación ignoradas, el 0.36% entre 28 y 37 semanas de gestación, el 0.23% entre 22 y 27 semanas, el 0.18% mayores de 42 semanas, el 0.004% menores de 22 semanas.

# %%
porcentaje = [(x/len(df2.TALLA_NAC)*100) for x in y_values2]
print(x_values2)
print(porcentaje)
# Out:
# ['40-49' '50-59' '30-39' '20-29' '>60' '1-19']
# [58.21976170495162, 40.76369101214992, 0.9207073790282962, 0.07699407403350692, 0.018523678899274677, 0.00032215093737869]

# %% [markdown]
# Aproximadamente 58% de nacidos nacen con una talla de 40 a 49 cm, el 40% nacen con una talla de 50 a 59 cm, el 0.92% con una talla de 30- 29 cm, el 0.07% con una talla entre 20 a 29 cm, el 0.01% con una talla mayor a 60 cm, 0.0003% con una talla de 1 a 19 cm.

# %% [markdown]
# # Tablas de contingencia
#
#
# *   Representación gráfica de una tabla de contingencia
# *   Proporciones asociadas a una tabla de contingencia

# %%
df2.loc[(df2.T_GES == "1"), "T_GES"], df2.loc[(df2.T_GES == "2"), "T_GES"] ="1-21", "22-27"
df2.loc[(df2.T_GES == "3"), "T_GES"],df2.loc[(df2.T_GES == "4"), 'T_GES'] = "28-37", "38-41"
df2.loc[(df2.T_GES == "5"), 'T_GES'], df2.loc[(df2.T_GES == "6"), 'T_GES'], df2.loc[(df2.T_GES == "9"), 'T_GES'] = ">42", "Ignorado", "NA"
df2.loc[(df2.TALLA_NAC == "1"), "TALLA_NAC"], df2.loc[(df2.TALLA_NAC == "2"), "TALLA_NAC"] ="1-19", "20-29"
df2.loc[(df2.TALLA_NAC == "3"), "TALLA_NAC"],df2.loc[(df2.TALLA_NAC == "4"), 'TALLA_NAC'] = "30-39", "40-49"
df2.loc[(df2.TALLA_NAC == "5"), 'TALLA_NAC'], df2.loc[(df2.TALLA_NAC == "6"), 'TALLA_NAC'], df2.loc[(df2.TALLA_NAC == "9"), 'TALLA_NAC'] = "50-59", ">60", "NA"
df2.T_GES, df2.TALLA_NAC = df2.T_GES.astype(str), df2.TALLA_NAC.astype(str)
df2.head(3)
# Out:
# <ipython-input-23-69ffc93f6a07>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.T_GES, df2.TALLA_NAC = df2.T_GES.astype(str), df2.TALLA_NAC.astype(str)
#           T_GES TALLA_NAC
# COD_DPTO
# 52        38-41     40-49
# 20        38-41     50-59
# 27        38-41     50-59

# %%
tabla_cont = pd.crosstab(df2.T_GES, df2["TALLA_NAC"])
tabla_cont
# Out:
# TALLA_NAC  1-19  20-29  30-39   40-49   50-59  >60
# T_GES
# 1-21          0     22      6       0       0    0
# 22-27         2    260   1872     102       0    0
# 28-37         0     53   3619   89212   37593    8
# 38-41         0     76    198  162543  322515  101
# >42           0      0      0     256     902    5
# Ignorado      0     67     21     959     434    1

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(6, 6))
heatmap = sns.heatmap(tabla_cont,  annot=True, fmt='d', cmap='YlGnBu', cbar=True)
plt.show()

# %%
res = stats.chi2_contingency(tabla_cont)
chi, valor_p, _, _ = res
print(f"El valor de la estadística Chi cuadrado es {chi} y el valor p es d {valor_p}")
# Out:
# El valor de la estadística Chi cuadrado es 299847.0666226869 y el valor p es d 0.0

# %% [markdown]
# *   Si valor p < 0.05 se rechaza la hipótesis nula
# *   Si valor p > 0.05 no se rechaza la hipótesis nula
#
# Como el valor p 0 < 0.05$ se rechaza la hipótesis nula, es decir, no se rechaza con una confianza del 95% que la hemoclasificación y el factor RH estén asociadas para los individuos recién nacidos en Colombia.

# %%
import math
coeficiente_contingencia = math.sqrt(chi/(chi + len(df2.T_GES)))
coeficiente_phi = math.sqrt(chi/len(df2.T_GES))
coeficiente_v_cramer = math.sqrt(chi/(len(df2.T_GES)*min(4-1, 2-1)))
print(f"Los coeficientes de contingencia, Phi y V de Cramer están respectivamente dados por {coeficiente_contingencia}, {coeficiente_phi} y {coeficiente_v_cramer}")
# Out:
# Los coeficientes de contingencia, Phi y V de Cramer están respectivamente dados por 0.5706856432960946, 0.6949676740063134 y 0.6949676740063134

# %%
import math
coeficiente_contingencia = math.sqrt(chi/(chi + len(df2.TALLA_NAC)))
coeficiente_phi = math.sqrt(chi/len(df2.TALLA_NAC))
coeficiente_v_cramer = math.sqrt(chi/(len(df2.TALLA_NAC)*min(4-1, 2-1)))
print(f"Los coeficientes de contingencia, Phi y V de Cramer están respectivamente dados por {coeficiente_contingencia}, {coeficiente_phi} y {coeficiente_v_cramer}")
# Out:
# Los coeficientes de contingencia, Phi y V de Cramer están respectivamente dados por 0.5706856432960946, 0.6949676740063134 y 0.6949676740063134

# %% [markdown]
# Son Coeficientes moderados  estan entre 0.5 y 0.7

# %% [markdown]
# De acuerdo con el artículo Landis, J. R., & Koch, G. G. (1977). The measurement of observer agreement for categorical data. biometrics, 159-174, el cual se puede consultar en el siguiente [link](https://www.jstor.org/stable/2529310), se tiene que la hemoclasificación y el factor RH están insignificantemente asociados
#
# Interpretación general
#
# *   Y depende ____ de X
# *   X y Y son ______ homogénas
# *   X y Y están ______ asociadas
#
# Donde ______ = nula ($Chi, \phi, V ≈ 0$), ______ = insignificantemente ($0 < Chi, \phi, V < 0.2$), ______ = discretamente ($0.2 < Chi, \phi, V < 0.4$), ______ = moderadamente, ($0.4 < Chi, \phi, V < 0.6$) ______ = sustancialmente ($0.6 < Chi, \phi, V < 0.8$) y ______ = fuertemente ($0.8 < Chi, \phi, V < 1$)

# %% [markdown]
# **CONCLUSIONES**
#
# 1. Comportamiento de la variable tiempo de gestación:
#
# - La gran mayoría de los nacimientos (78.2%) ocurren en el rango considerado a término, entre 38-41 semanas de gestación.
# - Existe un porcentaje significativo (21.0%) de casos donde el tiempo de gestación es "Ignorado" o no registrado.
# - Los nacimientos prematuros (menos de 37 semanas) o postérmino (más de 42 semanas) son relativamente poco frecuentes.
#
# 2. Comportamiento de la variable talla de nacimiento:
#
# - La mayoría de los recién nacidos (58.2%) tienen una talla entre 40-49 cm al nacer.
# - El segundo rango más común es de 50-59 cm, representando el 40.8% de los casos.
# - Las tallas extremas (menores de 30 cm o mayores de 60 cm) son muy poco frecuentes.
#
# 3. Asociación entre las variables:
#
# - Existe una aparente asociación entre el tiempo de gestación y la talla al nacer.
# - Los bebés nacidos a término (38-41 semanas) tienden a tener tallas entre 40-59 cm, con una concentración particularmente alta en el rango de 50-59 cm.
# - Se observa una tendencia donde mayor edad gestacional se asocia con mayor talla al nacer, especialmente en los rangos centrales de ambas variables.
#
# 4. Grado de dependencia o asociación:
#
# - La matriz de frecuencias en la Imagen 3 muestra una clara concentración de casos en la intersección de las categorías 38-41 semanas de gestación y 50-59 cm de talla, sugiriendo una fuerte asociación.
# - Sin embargo, para cuantificar con precisión el grado de dependencia, sería necesario realizar análisis estadísticos más avanzados, como pruebas de chi-cuadrado o cálculos de coeficientes de correlación.
# - La presencia de una cantidad significativa de casos con tiempo de gestación "Ignorado" podría afectar la interpretación de la relación entre estas variables.
#
#  los datos sugieren una clara relación entre el tiempo de gestación y la talla al nacer en Colombia, con una tendencia a que los nacimientos a término se asocien con tallas consideradas normales.
